# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style('white') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=13)

# %%
pal = sns.color_palette('Set2')
print(pal.as_hex())
# Out:
# ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f', '#e5c494', '#b3b3b3']

# %%
plt.xlabel('Nationality')
plt.ylabel('Average Rating')
plt.title('Barplot')
# Out:
# Text(0.5, 1.0, 'Barplot')

# %%
labels = ["Pyflow", "FlowFarneback",  "Lucas-Kanade", "HornSchunck"]
MSEN = [0.9371, 4.2001, 8.2191, 10.1838]
PEPN = [7.4015, 28.3936, 34.7867, 74.3190]

# %%
x = np.arange(len(labels))  # the label locations
width = 0.18# the width of the bars

fig, ax = plt.subplots(figsize=(10,10))
color = (252, 141, 98, 255)
rects1 = ax.bar(x - width/2, MSEN, width, label='MSEN',color= tuple(ti/255 for ti in color))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('MSE')
ax.set_title('Optical Flow MSE')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)

fig.tight_layout()

plt.show()
fig.savefig("./OF_metrhics_MSE.png")

x = np.arange(len(labels))  # the label locations
width = 0.18# the width of the bars

fig, ax = plt.subplots(figsize=(10,10))
color =(102, 194, 165, 255)
rects2 = ax.bar(x + width/2, PEPN, width, label='PEPN', color= tuple(ti/255 for ti in color))


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('PEPN')
ax.set_title('Optical Flow PEPN')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
fig.savefig("./OF_metrhics_PEPN.png")

# %%
x = np.arange(len(labels))  # the label locations
width = 0.18# the width of the bars

fig, ax = plt.subplots(figsize=(10,5))
color = (252, 141, 98, 255)

rects1 = ax.bar(x - width/2, MSEN, width, label='MSEN',color= tuple(ti/255 for ti in color))
color =(102, 194, 165, 255)
rects2 = ax.bar(x + width/2, PEPN, width, label='PEPN', color= tuple(ti/255 for ti in color))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('MSE')
ax2 = ax.twinx()
ax2.set_ylabel("PEPN %")
ax.set_title('Optical Flow methods')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
fig.savefig("./OF_metrhics.png")
